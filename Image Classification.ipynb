# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Read and Transform the data

# %%
data = pd.read_csv(r"D:\Capstone\Data\Train.csv")

# %%
data.head(5)
# Out:
#               ID                        filename growth_stage damage  extent  \
# 0  ID_1S8OOWQYCB  L427F01330C01S03961Rp02052.jpg            S     WD       0
# 1  ID_0MD959MIZ0      L1083F00930C39S12674Ip.jpg            V      G       0
# 2  ID_JRJCI4Q11V      24_initial_1_1463_1463.JPG            V      G       0
# 3  ID_DBO3ZGI1GM  L341F00167C01S00324Rp14178.jpg            M     DR      60
# 4  ID_ORZLWTEUUS      L1084F02394C39S13931Ip.jpg            V      G       0
#
#    season
# 0  SR2020
# 1  SR2021
# 2  LR2020
# 3  SR2020
# 4  SR2021

# %%
data.shape
# Out:
# (26068, 6)

# %%
data['year'] = data['season'].apply(lambda x: x[2:])
data['season'] = data['season'].apply(lambda x: x[0:2])
data['is_DR_damage'] = data['damage'].apply(lambda x: 'DR' if x=='DR' else 'Non-DR')

# %%
data.head()
# Out:
#               ID                        filename growth_stage damage  extent  \
# 0  ID_1S8OOWQYCB  L427F01330C01S03961Rp02052.jpg            S     WD       0
# 1  ID_0MD959MIZ0      L1083F00930C39S12674Ip.jpg            V      G       0
# 2  ID_JRJCI4Q11V      24_initial_1_1463_1463.JPG            V      G       0
# 3  ID_DBO3ZGI1GM  L341F00167C01S00324Rp14178.jpg            M     DR      60
# 4  ID_ORZLWTEUUS      L1084F02394C39S13931Ip.jpg            V      G       0
#
#   season  year is_DR_damage
# 0     SR  2020       Non-DR
# 1     SR  2021       Non-DR
# 2     LR  2020       Non-DR
# 3     SR  2020           DR
# 4     SR  2021       Non-DR

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26068 entries, 0 to 26067
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            26068 non-null  object
#  1   filename      26068 non-null  object
#  2   growth_stage  26068 non-null  object
#  3   damage        26068 non-null  object
#  4   extent        26068 non-null  int64
#  5   season        26068 non-null  object
#  6   year          26068 non-null  object
#  7   is_DR_damage  26068 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.6+ MB

# %%
data[['growth_stage','damage','season','year']].astype('category').describe()
# Out:
#        growth_stage damage season   year
# count         26068  26068  26068  26068
# unique            4      8      2      2
# top               V      G     SR   2021
# freq          10015  11623  16090  17872

# %% [markdown]
# ### Data Cleaning

# %%
# Drop Duplicates
data.drop_duplicates(inplace=True)

# %%
# Check for Missing Data
for column in data.columns:
    print(f"{column: <15}:{data[column].isnull().sum()}")
# Out:
# ID             :0
# filename       :0
# growth_stage   :0
# damage         :0
# extent         :0
# season         :0
# year           :0
# is_DR_damage   :0

# %% [markdown]
# ### Exploratory Data Analysis

# %%
plt.figure(figsize=(2,3))
sns.countplot(x='is_DR_damage',data=data)
plt.ylabel("No.of Data points")
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.histplot(x='extent',data=data, kde=True)
plt.show()

# %%
#plt.figure(figsize=(2,3))
sns.boxplot(x='damage',y='extent',data = data, hue='year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #plt.figure(figsize=(2,3))
# ----> 2 sns.boxplot(x='damage',y='extent',data = data, hue='year')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
data_dr = data[data['damage']=='DR']
data_dr.head()
# Out:
#                ID                        filename growth_stage damage  extent  \
# 3   ID_DBO3ZGI1GM  L341F00167C01S00324Rp14178.jpg            M     DR      60
# 8   ID_BVNP8C4M1N  L331F04678C01S11060Rp30683.jpg            M     DR      40
# 9   ID_MFL3FVUKDA  L133F00737C01S06945Rp25674.jpg            F     DR      60
# 19  ID_NFYJ8T2V5W  L432F01720C01S04931Rp13768.jpg            M     DR      20
# 23  ID_C74KHW4OK5  L133F03014C01S00293Rp10017.jpg            M     DR      50
#
#    season  year is_DR_damage
# 3      SR  2020           DR
# 8      LR  2021           DR
# 9      LR  2021           DR
# 19     SR  2020           DR
# 23     SR  2020           DR

# %%
data_dr.shape
# Out:
# (4516, 8)

# %%
plt.figure(figsize=(5,3))
sns.histplot(x='extent',data=data_dr, kde=True)
plt.show()

# %%
# Distribution of images across seasons and year

plt.figure(figsize=(2,3))
sns.countplot(x='season',data=data_dr)
plt.ylabel("No.of Data points")
plt.show()

# %%
plt.figure(figsize=(2,3))
sns.boxplot(x='season',y='extent',data = data_dr)
plt.show()

# %%
# Distribution of images across growth stage and year

plt.figure(figsize=(4,3))
sns.countplot(x='growth_stage',data=data_dr, hue='year')
plt.ylabel("No.of Data points")
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x='growth_stage',y='extent',data = data_dr)
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.boxplot(x='growth_stage',y='extent',data = data_dr, hue='year')
plt.show()

# %% [markdown]
# ### Image Preprocessing

# %%
#Check for corrupted image

data_img = data.copy(deep=True)


data_img['is_corrupted'] = ''
data_img.head()
# Out:
#               ID                        filename growth_stage damage  extent  \
# 0  ID_1S8OOWQYCB  L427F01330C01S03961Rp02052.jpg            S     WD       0
# 1  ID_0MD959MIZ0      L1083F00930C39S12674Ip.jpg            V      G       0
# 2  ID_JRJCI4Q11V      24_initial_1_1463_1463.JPG            V      G       0
# 3  ID_DBO3ZGI1GM  L341F00167C01S00324Rp14178.jpg            M     DR      60
# 4  ID_ORZLWTEUUS      L1084F02394C39S13931Ip.jpg            V      G       0
#
#   season  year is_DR_damage is_corrupted
# 0     SR  2020       Non-DR
# 1     SR  2021       Non-DR
# 2     LR  2020       Non-DR
# 3     SR  2020           DR
# 4     SR  2021       Non-DR

# %%
data_img.reset_index(inplace = True)
data_img.drop('index',axis=1,inplace=True)

# %%
data_img.head()
# Out:
#               ID                        filename growth_stage damage  extent  \
# 0  ID_1S8OOWQYCB  L427F01330C01S03961Rp02052.jpg            S     WD       0
# 1  ID_0MD959MIZ0      L1083F00930C39S12674Ip.jpg            V      G       0
# 2  ID_JRJCI4Q11V      24_initial_1_1463_1463.JPG            V      G       0
# 3  ID_DBO3ZGI1GM  L341F00167C01S00324Rp14178.jpg            M     DR      60
# 4  ID_ORZLWTEUUS      L1084F02394C39S13931Ip.jpg            V      G       0
#
#   season  year is_DR_damage is_corrupted
# 0     SR  2020       Non-DR
# 1     SR  2021       Non-DR
# 2     LR  2020       Non-DR
# 3     SR  2020           DR
# 4     SR  2021       Non-DR

# %%
folder_path = "D:\Capstone\Data\\train"


def isCorruptedImage(fname):
    fpath = os.path.join(folder_path, fname)
    try:
        fobj = open(fpath, "rb")
        is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
    finally:
        fobj.close()
    if not is_jfif:
        return True
    return False

# %%
isCorruptedImage('L341F00167C01S00324Rp14178.jpg')
# Out:
# False

# %%
data_img['is_corrupted'] = data_img['filename'].apply(isCorruptedImage)
data_img['is_corrupted'].sum()
# Out:
# 0

# %%
# No corrupted images found

# %%
#Treating Imbalances in the dataset with Image Augmentation

# %% [markdown]
# ### Without treating the imbalances

# %%
data.head()
# Out:
#               ID                        filename growth_stage damage  extent  \
# 0  ID_1S8OOWQYCB  L427F01330C01S03961Rp02052.jpg            S     WD       0
# 1  ID_0MD959MIZ0      L1083F00930C39S12674Ip.jpg            V      G       0
# 2  ID_JRJCI4Q11V      24_initial_1_1463_1463.JPG            V      G       0
# 3  ID_DBO3ZGI1GM  L341F00167C01S00324Rp14178.jpg            M     DR      60
# 4  ID_ORZLWTEUUS      L1084F02394C39S13931Ip.jpg            V      G       0
#
#   season  year is_DR_damage
# 0     SR  2020       Non-DR
# 1     SR  2021       Non-DR
# 2     LR  2020       Non-DR
# 3     SR  2020           DR
# 4     SR  2021       Non-DR

# %%
data['is_DR_damage'] = data['is_DR_damage'].astype('str')

# %%
num_images = data.shape[0]
print("Total no.of images: ",num_images)
# Out:
# Total no.of images:  26068

# %%
import cv2

SIZE = 256

train_images = []
train_labels = []

for i in range(num_images):
    fname = data['filename'][i]
    img_path = os.path.join(folder_path, fname)
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    img = cv2.resize(img, (SIZE, SIZE))
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    train_images.append(img)
    train_labels.append(data['is_DR_damage'][i])

# %%
import numpy as np

train_images = np.array(train_images)
train_labels = np.array(train_labels)

# %%
from random import sample

for i in sample(range(len(train_labels)), 4):
    plt.figure(figsize=(3,3))
    plt.imshow(train_images[i])
    plt.title(train_labels[i])
    plt.show()

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

# %%
from sklearn.model_selection import train_test_split

train_img, test_img, train_labels, test_labels = train_test_split(train_images, train_labels, test_size=0.10, random_state=42)
train_img, val_img, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.10, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[241], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 train_img, test_img, train_labels, test_labels = train_test_split(train_images, train_labels, test_size=0.10, random_state=42)
#       4 train_img, val_img, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.10, random_state=42)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:2614, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2611 if n_arrays == 0:
#    2612     raise ValueError("At least one array required as input")
# -> 2614 arrays = indexable(*arrays)
#    2616 n_samples = _num_samples(arrays[0])
#    2617 n_train, n_test = _validate_shuffle_split(
#    2618     n_samples, test_size, train_size, default_test_size=0.25
#    2619 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:455, in indexable(*iterables)
#     436 """Make arrays indexable for cross-validation.
#     437
#     438 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     451     sparse matrix, or dataframe) or `None`.
#     452 """
#     454 result = [_make_indexable(X) for X in iterables]
# --> 455 check_consistent_length(*result)
#     456 return result
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:409, in check_consistent_length(*arrays)
#     407 uniques = np.unique(lengths)
#     408 if len(uniques) > 1:
# --> 409     raise ValueError(
#     410         "Found input variables with inconsistent numbers of samples: %r"
#     411         % [int(l) for l in lengths]
#     412     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [26068, 23461]

# %%
train
